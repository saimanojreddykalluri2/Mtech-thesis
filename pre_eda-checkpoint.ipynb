# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('after_filling_Na_project_mtp.xlsx')

# %%
df
# Out:
#       Unnamed: 0  Fatigue_Strength                name  Brinell_Hardness  \
# 0              8                47   1350-H26-Aluminum              38.0
# 1              9                50   1350-H19-Aluminum              45.0
# 2             10                25     1350-O-Aluminum              20.0
# 3             11                48   1350-H22-Aluminum              27.0
# 4             12                55     5457-O-Aluminum              32.0
# ...          ...               ...                 ...               ...
# 1029        1081                50   1050-H16-Aluminum              35.0
# 1030        1082                49   1050-H14-Aluminum              35.0
# 1031        1083                56   1050-H12-Aluminum              35.0
# 1032        1084                57   1050-H22-Aluminum              35.0
# 1033        1085                31  1050-H112-Aluminum              35.0
#
#       Shear_Strength  Tensile_Strength_Ultimate_UTS  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Fatigue_Strength', 'name', 'Brinell_Hardness',
#        'Shear_Strength', 'Tensile_Strength_Ultimate_UTS',
#        'Tensile_Strength_Yield_Proof', 'type', 'tempers', 'Ag_low', 'Ag_high',
#        'Al_low', 'Al_high', 'B_low', 'B_high', 'Be_low', 'Be_high', 'Bi_low',
#        'Bi_high', 'Co_low', 'Co_high', 'Cr_low', 'Cr_high', 'Cu_low',
#        'Cu_high', 'Fe_low', 'Fe_high', 'Ga_low', 'Ga_high', 'Li_low',
#        'Li_high', 'Mg_low', 'Mg_high', 'Mn_low', 'Mn_high', 'Ni_low',
#        'Ni_high', 'Pb_low', 'Pb_high', 'Si_low', 'Si_high', 'Sn_low',
#        'Sn_high', 'Ti_low', 'Ti_high', 'V_low', 'V_high', 'Zn_low', 'Zn_high',
#        'Zr_low', 'Zr_high'],
#       dtype='object')

# %%
df1 = df.drop(['Unnamed: 0','name',],axis=1)

# %%
df1
# Out:
#       Fatigue_Strength  Brinell_Hardness  Shear_Strength  \
# 0                   47              38.0              66
# 1                   50              45.0             110
# 2                   25              20.0              55
# 3                   48              27.0              55
# 4                   55              32.0              85
# ...                ...               ...             ...
# 1029                50              35.0              76
# 1030                49              35.0              69
# 1031                56              35.0              57
# 1032                57              35.0              57
# 1033                31              35.0              52
#
#       Tensile_Strength_Ultimate_UTS  Tensile_Strength_Yield_Proof     type  \
# 0                               110                            84  Wrought
# 1                               180                           170  Wrought
# ...

# %%
df1['Ag'] = (df1['Ag_low'] + df1['Ag_high'])/2

# %%
df1
# Out:
#       Fatigue_Strength  Brinell_Hardness  Shear_Strength  \
# 0                   47              38.0              66
# 1                   50              45.0             110
# 2                   25              20.0              55
# 3                   48              27.0              55
# 4                   55              32.0              85
# ...                ...               ...             ...
# 1029                50              35.0              76
# 1030                49              35.0              69
# 1031                56              35.0              57
# 1032                57              35.0              57
# 1033                31              35.0              52
#
#       Tensile_Strength_Ultimate_UTS  Tensile_Strength_Yield_Proof     type  \
# 0                               110                            84  Wrought
# 1                               180                           170  Wrought
# ...

# %%
df1['Ti'] = (df1['Ti_low'] + df1['Ti_high'])/2

# %%
df1
# Out:
#       Fatigue_Strength  Brinell_Hardness  Shear_Strength  \
# 0                   47              38.0              66
# 1                   50              45.0             110
# 2                   25              20.0              55
# 3                   48              27.0              55
# 4                   55              32.0              85
# ...                ...               ...             ...
# 1029                50              35.0              76
# 1030                49              35.0              69
# 1031                56              35.0              57
# 1032                57              35.0              57
# 1033                31              35.0              52
#
#       Tensile_Strength_Ultimate_UTS  Tensile_Strength_Yield_Proof     type  \
# 0                               110                            84  Wrought
# 1                               180                           170  Wrought
# ...

# %%
df1.columns
# Out:
# Index(['Fatigue_Strength', 'Brinell_Hardness', 'Shear_Strength',
#        'Tensile_Strength_Ultimate_UTS', 'Tensile_Strength_Yield_Proof', 'type',
#        'tempers', 'Ag_low', 'Ag_high', 'Al_low', 'Al_high', 'B_low', 'B_high',
#        'Be_low', 'Be_high', 'Bi_low', 'Bi_high', 'Co_low', 'Co_high', 'Cr_low',
#        'Cr_high', 'Cu_low', 'Cu_high', 'Fe_low', 'Fe_high', 'Ga_low',
#        'Ga_high', 'Li_low', 'Li_high', 'Mg_low', 'Mg_high', 'Mn_low',
#        'Mn_high', 'Ni_low', 'Ni_high', 'Pb_low', 'Pb_high', 'Si_low',
#        'Si_high', 'Sn_low', 'Sn_high', 'Ti_low', 'Ti_high', 'V_low', 'V_high',
#        'Zn_low', 'Zn_high', 'Zr_low', 'Zr_high', 'Ag', 'Ti'],
#       dtype='object')

# %%
df1['Al'] = (df1['Al_low'] + df1['Al_high'])/2
df1['B'] = (df1['B_low'] + df1['B_high'])/2
df1['Be'] = (df1['Be_low'] + df1['Be_high'])/2
df1['Bi'] = (df1['Bi_low'] + df1['Bi_high'])/2
df1['Co'] = (df1['Co_low'] + df1['Co_high'])/2
df1['Cr'] = (df1['Cr_low'] + df1['Cr_high'])/2
df1['Cu'] = (df1['Cu_low'] + df1['Cu_high'])/2
df1['Fe'] = (df1['Fe_low'] + df1['Fe_high'])/2
df1['Ga'] = (df1['Ga_low'] + df1['Ga_high'])/2
df1['Li'] = (df1['Li_low'] + df1['Li_high'])/2
df1['Mg'] = (df1['Mg_low'] + df1['Mg_high'])/2
df1['Mn'] = (df1['Mn_low'] + df1['Mn_high'])/2
df1['Ni'] = (df1['Ni_low'] + df1['Ni_high'])/2
df1['Pb'] = (df1['Pb_low'] + df1['Pb_high'])/2
df1['Si'] = (df1['Si_low'] + df1['Si_high'])/2
df1['Sn'] = (df1['Sn_low'] + df1['Sn_high'])/2
df1['V'] = (df1['V_low'] + df1['V_high'])/2
df1['Zn'] = (df1['Zn_low'] + df1['Zn_high'])/2
df1['Zr'] = (df1['Zr_low'] + df1['Zr_high'])/2

# %%
df2 = df1.drop(['Ag_low', 'Ag_high', 'Al_low', 'Al_high', 'B_low', 'B_high',
       'Be_low', 'Be_high', 'Bi_low', 'Bi_high', 'Co_low', 'Co_high', 'Cr_low',
       'Cr_high', 'Cu_low', 'Cu_high', 'Fe_low', 'Fe_high', 'Ga_low',
       'Ga_high', 'Li_low', 'Li_high', 'Mg_low', 'Mg_high', 'Mn_low',
       'Mn_high', 'Ni_low', 'Ni_high', 'Pb_low', 'Pb_high', 'Si_low',
       'Si_high', 'Sn_low', 'Sn_high', 'Ti_low', 'Ti_high', 'V_low', 'V_high',
       'Zn_low', 'Zn_high', 'Zr_low', 'Zr_high'],axis=1)

# %%
df2.columns
# Out:
# Index(['Fatigue_Strength', 'Brinell_Hardness', 'Shear_Strength',
#        'Tensile_Strength_Ultimate_UTS', 'Tensile_Strength_Yield_Proof', 'type',
#        'tempers', 'Ag', 'Ti', 'Al', 'B', 'Be', 'Bi', 'Co', 'Cr', 'Cu', 'Fe',
#        'Ga', 'Li', 'Mg', 'Mn', 'Ni', 'Pb', 'Si', 'Sn', 'V', 'Zn', 'Zr'],
#       dtype='object')

# %%
sns.boxplot(df2['Brinell_Hardness'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Brinell_Hardness'>

# %%
sns.boxplot(df2['Fatigue_Strength'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fatigue_Strength'>

# %%
sns.boxplot(df2['Shear_Strength'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shear_Strength'>

# %%
sns.boxplot(df2['Tensile_Strength_Ultimate_UTS'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tensile_Strength_Ultimate_UTS'>

# %%
sns.boxplot(df2['Tensile_Strength_Yield_Proof'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tensile_Strength_Yield_Proof'>

# %%
num_df2 = df2.drop(['type',
       'tempers'],axis=1)

# %%
column=list(num_df2.columns)
for i in column:
    plt.figure(figsize=(4,4))
    sns.boxplot(y=num_df2[i],data=num_df2)
    plt.xlabel(str(i))
    plt.ylabel('Values')
    plt.title('Box_PLOT OF '+ str(i))
    plt.savefig('Box_'+str(i) + '.png')
# Out:
# C:\Users\kallu\AppData\Local\Temp\ipykernel_46612\712435943.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(4,4))

# %%
column=list(df2.columns)
for i in column:    
    plt.figure(figsize=(4,4))
    plt.hist(df2[i])
    plt.xlabel(str(i))
    plt.ylabel('Frequency')
    plt.title('HISTOGRAM PLOT OF '+ str(i))
    plt.savefig('Hist'+str(i)+'.png')
# Out:
# C:\Users\kallu\AppData\Local\Temp\ipykernel_46612\3402045072.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(4,4))

# %%
plt.figure(figsize=(20,20),dpi=500)
sns.countplot(df['tempers'])
# Out:
# C:\Users\kallu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tempers', ylabel='count'>

# %%
column=list(df2.columns)
for i in column:    
    plt.figure(figsize=(4,4))
    sns.scatterplot(y= df2['Fatigue_Strength'],x=df2[i])
    plt.xlabel(str(i))
    plt.ylabel('Fatigue_Strength')
    plt.title('Scatter Plot of Fatigue Strength VS '+ str(i))
# Out:
# C:\Users\kallu\AppData\Local\Temp\ipykernel_46612\852623577.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(4,4))

# %%
plt.figure(figsize = (20,20),dpi = 201)
sns.heatmap(df2.corr(),annot=True)
# Out:
# <AxesSubplot:>
